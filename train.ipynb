# %%
import nltk
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\mgopa\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
#libraries

import random
from keras.optimizers import SGD
from keras.layers import Dense, Dropout
from keras.models import load_model
from keras.models import Sequential
import numpy as np
import pickle
import json
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mgopa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\mgopa\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#init file
words=[]
classes=[]
documents = []
ignore_words=["?","!"]
data_file=open("intents.json").read()
intents = json.loads(data_file)

# %%
#words
for intent in intents["intents"]: 
  for pattern in intent["patterns"]:
    #take each word and tokenize it 
    w=nltk.word_tokenize(pattern)
    words.extend(w)
    #adding documents
    documents.append((w, intent["tag"]))
    # adding classes to our class list
    if intent["tag"] not in classes: 
      classes.append(intent["tag"])

# %%
#lemmatizer

words=[lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words=sorted(list(set(words)))
classes=sorted(list(set(classes)))
print(len(documents), "documents")
print(len(classes), "classes", classes)
print(len(words), "unique lemmatized words", words)
pickle.dump(words, open("words.pkl", "wb"))
pickle.dump(classes, open("classes.pkl", "wb"))
# Out:
# 261 documents
# 28 classes ['admission', 'canteen', 'college intake', 'committee', 'course', 'event', 'facilities', 'fees', 'goodbye', 'greeting', 'hostel', 'hours', 'infrastructure', 'ithod', 'library', 'location', 'menu', 'number', 'placement', 'principal', 'ragging', 'salutaion', 'sem', 'size', 'syllabus', 'task', 'transport', 'vacation']
# 195 unique lemmatized words ["'s", 'a', 'about', 'active', 'address', 'admission', 'allotment', 'am', 'and', 'antiragging', 'any', 'anyone', 'are', 'at', 'attend', 'available', 'average', 'be', 'between', 'big', 'book', 'branch', 'bus', 'bye', 'cafetaria', 'call', 'campus', 'can', 'canteen', 'capacity', 'case', 'college', 'come', 'committe', 'committee', 'company', 'conducted', 'contact', 'course', 'cya', 'date', 'day', 'detail', 'different', 'distance', 'do', 'doe', 'done', 'each', 'end', 'event', 'exam', 'facility', 'far', 'fee', 'first', 'food', 'for', 'from', 'function', 'get', 'give', 'go', 'good', 'goodbye', 'got', 'gtg', 'guy', 'gvp', 'gvpce', 'have', 'held', 'hello', 'help', 'here', 'heyy', 'hi', 'history', 'hod', 'holiday', 'hostel', 'hour', 'how', 'i', 'in', 'incident', 'info', 'information', 'infrastructure', 'intake', 'is', 'it', 'job', 'junior', 'k', 'later', 'leaving', 'library', 'list', 'located', 'location', 'long', 'many', 'max', 'maximum', 'me', 'menu', 'mode', 'more', 'much', 'my', 'name', 'nice', 'no', 'number', 'of', 'offer', 'offered', 'office', 'ok', 'okay', 'okie', 'okk', 'on', 'open', 'operation', 'organised', 'package', 'per', 'phone', 'placement', 'practice', 'principal', 'process', 'provide', 'provided', 'ragging', 'reach', 'recruitment', 'route', 'saturday', 'schedule', 'seat', 'see', 'sem', 'semester', 'servive', 'should', 'size', 'something', 'start', 'student', 'stundent', 'syllabus', 'take', 'taken', 'talk', 'telephone', 'tell', 'thank', 'thanks', 'the', 'there', 'thing', 'time', 'timetable', 'timing', 'to', 'transportation', 'travelling', 'tyyl', 'u', 'up', 'use', 'vacation', 'visit', 'we', 'well', 'what', 'whats', 'whatsup', 'whatv', 'when', 'where', 'wheres', 'which', 'who', 'why', 'will', 'work', 'working', 'ya', 'year', 'you', 'your']

# %%
#training initializer
#initializing training data
training=[]
output_empty=[0]*len(classes)
for doc in documents:
  #initializing bag of words
  bag=[]
  #list of tokenized words for the pattern
  pattern_words=doc[0]
  #lemmatize each word - create base word, in attempt to represent related words
  pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words] 
  #create our bag of words array with 1, if word match found in current pattern
  for w in words:
    bag.append(1) if w in pattern_words else bag.append(0)
  # output is a '0' for each tag and '1' for current tag (for each pattern)
  output_row=list(output_empty) 
  output_row[classes.index(doc[1])] = 1
  training.append( [bag,output_row])

# %%
#shuffle our features and turn into np.array 
random.shuffle(training)
training = np.array(training)
#create train and test lists. X-patterns, Y - intents
train_x=list(training[:, 0])
train_y=list(training[:, 1])
print("Training data created")
# Out:
# Training data created
# C:\Users\mgopa\AppData\Local\Temp\ipykernel_1164\1026515650.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)

# %%
# actual training

#Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation="softmax"))
model.summary()
#Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model

sgd=SGD(lr=0.01, decay=1e-6,momentum=0.9,nesterov=True)
model.compile(loss="categorical_crossentropy", optimizer=sgd, metrics=["accuracy"])
# for choosing an optimal number of training epochs to avoid underfitting or overfitting use an early stopping callback to keras
# based on either accuracy or loos monitoring. If the loss is being monitored, training comes to halt when there is an
#increment observed in loss values. Or, If accuracy is being monitored, training comes to halt when there is decrement observed in accuracy values.
# fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save("chatbot_mode.h5", hist)
print("model created")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               25088
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 28)                1820
#
# =================================================================
# Total params: 35,164
# Trainable params: 35,164
# Non-trainable params: 0
# _________________________________________________________________
# c:\Users\mgopa\miniconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/200
# 53/53 [==============================] - 3s 2ms/step - loss: 3.3052 - accuracy: 0.0690
# Epoch 2/200
# 53/53 [==============================] - 0s 2ms/step - loss: 3.1573 - accuracy: 0.1149
# Epoch 3/200
# 53/53 [==============================] - 0s 2ms/step - loss: 2.9980 - accuracy: 0.1533
# Epoch 4/200
# 53/53 [==============================] - 0s 2ms/step - loss: 2.7957 - accuracy: 0.2337
# Epoch 5/200
# 53/53 [==============================] - 0s 2ms/step - loss: 2.4906 - accuracy: 0.3180
# Epoch 6/200
# 53/53 [==============================] - 0s 2ms/step - loss: 2.2765 - accuracy: 0.3640
# Epoch 7/200
# 53/53 [==============================] - 0s 2ms/step - loss: 2.0413 - accuracy: 0.4253
# Epoch 8/200
# 53/53 [==============================] - 0s 2ms/step - loss: 1.8391 - accuracy: 0.4636
# Epoch 9/200
# 53/53 [==============================] - 0s 2ms/step - loss: 1.6453 - accuracy: 0.5211
# Epoch 10/200
# 53/53 [==============================] - 0s 2ms/step - loss: 1.5232 - accuracy: 0.5785
# Epoch 11/200
# 53/53 [==============================] - 0s 2ms/step - loss: 1.3330 - accuracy: 0.6475
# Epoch 12/200
# 53/53 [==============================] - 0s 2ms/step - loss: 1.2360 - accuracy: 0.6245
# Epoch 13/200
# 53/53 [==============================] - 0s 2ms/step - loss: 1.1800 - accuracy: 0.6820
# Epoch 14/200
# 53/53 [==============================] - 0s 1ms/step - loss: 1.0469 - accuracy: 0.6973
# Epoch 15/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.9570 - accuracy: 0.7165
# Epoch 16/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.8715 - accuracy: 0.7280
# Epoch 17/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.8357 - accuracy: 0.7701
# Epoch 18/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.7529 - accuracy: 0.7931
# Epoch 19/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6635 - accuracy: 0.7931
# Epoch 20/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6537 - accuracy: 0.8199
# Epoch 21/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.5916 - accuracy: 0.8161
# Epoch 22/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.5547 - accuracy: 0.8429
# Epoch 23/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.5466 - accuracy: 0.8238
# Epoch 24/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.4682 - accuracy: 0.8697
# Epoch 25/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3927 - accuracy: 0.9080
# Epoch 26/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.4385 - accuracy: 0.8659
# Epoch 27/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.4766 - accuracy: 0.8889
# Epoch 28/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.4020 - accuracy: 0.8812
# Epoch 29/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3191 - accuracy: 0.9195
# Epoch 30/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3690 - accuracy: 0.8966
# Epoch 31/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.3423 - accuracy: 0.8736
# Epoch 32/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3496 - accuracy: 0.8927
# Epoch 33/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3184 - accuracy: 0.9234
# Epoch 34/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3224 - accuracy: 0.9119
# Epoch 35/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3095 - accuracy: 0.9080
# Epoch 36/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2520 - accuracy: 0.9540
# Epoch 37/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2159 - accuracy: 0.9387
# Epoch 38/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3158 - accuracy: 0.9157
# Epoch 39/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2191 - accuracy: 0.9464
# Epoch 40/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2796 - accuracy: 0.9119
# Epoch 41/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2720 - accuracy: 0.9310
# Epoch 42/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1763 - accuracy: 0.9579
# Epoch 43/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1964 - accuracy: 0.9579
# Epoch 44/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2284 - accuracy: 0.9272
# Epoch 45/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2178 - accuracy: 0.9272
# Epoch 46/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1799 - accuracy: 0.9617
# Epoch 47/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2240 - accuracy: 0.9272
# Epoch 48/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2010 - accuracy: 0.9502
# Epoch 49/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.2280 - accuracy: 0.9310
# Epoch 50/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1867 - accuracy: 0.9502
# Epoch 51/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1940 - accuracy: 0.9540
# Epoch 52/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1808 - accuracy: 0.9540
# Epoch 53/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1558 - accuracy: 0.9502
# Epoch 54/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1573 - accuracy: 0.9464
# Epoch 55/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1321 - accuracy: 0.9617
# Epoch 56/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1558 - accuracy: 0.9655
# Epoch 57/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1457 - accuracy: 0.9502
# Epoch 58/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1723 - accuracy: 0.9464
# Epoch 59/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1510 - accuracy: 0.9540
# Epoch 60/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0860 - accuracy: 0.9847
# Epoch 61/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1737 - accuracy: 0.9655
# Epoch 62/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1522 - accuracy: 0.9579
# Epoch 63/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1938 - accuracy: 0.9387
# Epoch 64/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1156 - accuracy: 0.9579
# Epoch 65/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1276 - accuracy: 0.9693
# Epoch 66/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1711 - accuracy: 0.9617
# Epoch 67/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1253 - accuracy: 0.9617
# Epoch 68/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1093 - accuracy: 0.9732
# Epoch 69/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1133 - accuracy: 0.9617
# Epoch 70/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1534 - accuracy: 0.9540
# Epoch 71/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1265 - accuracy: 0.9655
# Epoch 72/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1226 - accuracy: 0.9655
# Epoch 73/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1599 - accuracy: 0.9464
# Epoch 74/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1257 - accuracy: 0.9655
# Epoch 75/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1140 - accuracy: 0.9540
# Epoch 76/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0934 - accuracy: 0.9770
# Epoch 77/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1043 - accuracy: 0.9617
# Epoch 78/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1456 - accuracy: 0.9540
# Epoch 79/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1591 - accuracy: 0.9425
# Epoch 80/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1004 - accuracy: 0.9655
# Epoch 81/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0995 - accuracy: 0.9770
# Epoch 82/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0909 - accuracy: 0.9770
# Epoch 83/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1053 - accuracy: 0.9693
# Epoch 84/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0846 - accuracy: 0.9808
# Epoch 85/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0808 - accuracy: 0.9885
# Epoch 86/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0825 - accuracy: 0.9847
# Epoch 87/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0746 - accuracy: 0.9808
# Epoch 88/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1198 - accuracy: 0.9655
# Epoch 89/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1149 - accuracy: 0.9617
# Epoch 90/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1195 - accuracy: 0.9655
# Epoch 91/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0866 - accuracy: 0.9770
# Epoch 92/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1050 - accuracy: 0.9655
# Epoch 93/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1223 - accuracy: 0.9502
# Epoch 94/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1045 - accuracy: 0.9579
# Epoch 95/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0845 - accuracy: 0.9770
# Epoch 96/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1142 - accuracy: 0.9655
# Epoch 97/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1008 - accuracy: 0.9732
# Epoch 98/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0743 - accuracy: 0.9732
# Epoch 99/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0794 - accuracy: 0.9732
# Epoch 100/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0729 - accuracy: 0.9847
# Epoch 101/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0796 - accuracy: 0.9770
# Epoch 102/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0785 - accuracy: 0.9847
# Epoch 103/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0679 - accuracy: 0.9808
# Epoch 104/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0786 - accuracy: 0.9808
# Epoch 105/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1123 - accuracy: 0.9770
# Epoch 106/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0962 - accuracy: 0.9808
# Epoch 107/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0666 - accuracy: 0.9847
# Epoch 108/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0730 - accuracy: 0.9808
# Epoch 109/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1029 - accuracy: 0.9655
# Epoch 110/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0918 - accuracy: 0.9732
# Epoch 111/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0926 - accuracy: 0.9693
# Epoch 112/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0783 - accuracy: 0.9693
# Epoch 113/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0470 - accuracy: 0.9885
# Epoch 114/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1034 - accuracy: 0.9655
# Epoch 115/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0835 - accuracy: 0.9847
# Epoch 116/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1296 - accuracy: 0.9579
# Epoch 117/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0730 - accuracy: 0.9847
# Epoch 118/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0534 - accuracy: 0.9885
# Epoch 119/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0503 - accuracy: 0.9885
# Epoch 120/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0560 - accuracy: 0.9885
# Epoch 121/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0683 - accuracy: 0.9770
# Epoch 122/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0695 - accuracy: 0.9770
# Epoch 123/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0738 - accuracy: 0.9808
# Epoch 124/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0738 - accuracy: 0.9732
# Epoch 125/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0687 - accuracy: 0.9885
# Epoch 126/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0437 - accuracy: 0.9885
# Epoch 127/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0676 - accuracy: 0.9770
# Epoch 128/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0720 - accuracy: 0.9847
# Epoch 129/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0428 - accuracy: 0.9885
# Epoch 130/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0753 - accuracy: 0.9693
# Epoch 131/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0776 - accuracy: 0.9655
# Epoch 132/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1026 - accuracy: 0.9617
# Epoch 133/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0815 - accuracy: 0.9732
# Epoch 134/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0616 - accuracy: 0.9847
# Epoch 135/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0432 - accuracy: 0.9885
# Epoch 136/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0991 - accuracy: 0.9732
# Epoch 137/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0476 - accuracy: 0.9885
# Epoch 138/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0645 - accuracy: 0.9770
# Epoch 139/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0451 - accuracy: 0.9885
# Epoch 140/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0891 - accuracy: 0.9579
# Epoch 141/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0839 - accuracy: 0.9808
# Epoch 142/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1046 - accuracy: 0.9655
# Epoch 143/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0705 - accuracy: 0.9732
# Epoch 144/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0494 - accuracy: 0.9808
# Epoch 145/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0641 - accuracy: 0.9847
# Epoch 146/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0531 - accuracy: 0.9885
# Epoch 147/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0799 - accuracy: 0.9808
# Epoch 148/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0560 - accuracy: 0.9808
# Epoch 149/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0780 - accuracy: 0.9770
# Epoch 150/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.1188 - accuracy: 0.9579
# Epoch 151/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0436 - accuracy: 0.9923
# Epoch 152/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0884 - accuracy: 0.9732
# Epoch 153/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0599 - accuracy: 0.9770
# Epoch 154/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0481 - accuracy: 0.9885
# Epoch 155/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1044 - accuracy: 0.9655
# Epoch 156/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0366 - accuracy: 0.9847
# Epoch 157/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0401 - accuracy: 0.9962
# Epoch 158/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0421 - accuracy: 0.9847
# Epoch 159/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0614 - accuracy: 0.9808
# Epoch 160/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0655 - accuracy: 0.9808
# Epoch 161/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0497 - accuracy: 0.9847
# Epoch 162/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0747 - accuracy: 0.9770
# Epoch 163/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0784 - accuracy: 0.9770
# Epoch 164/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0624 - accuracy: 0.9808
# Epoch 165/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0500 - accuracy: 0.9847
# Epoch 166/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0513 - accuracy: 0.9808
# Epoch 167/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0351 - accuracy: 0.9885
# Epoch 168/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0377 - accuracy: 0.9885
# Epoch 169/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0452 - accuracy: 0.9885
# Epoch 170/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0755 - accuracy: 0.9693
# Epoch 171/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0408 - accuracy: 0.9847
# Epoch 172/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0641 - accuracy: 0.9770
# Epoch 173/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0398 - accuracy: 0.9847
# Epoch 174/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0341 - accuracy: 0.9885
# Epoch 175/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0500 - accuracy: 0.9847
# Epoch 176/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0353 - accuracy: 0.9847
# Epoch 177/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0830 - accuracy: 0.9808
# Epoch 178/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0457 - accuracy: 0.9923
# Epoch 179/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0323 - accuracy: 0.9885
# Epoch 180/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0567 - accuracy: 0.9885
# Epoch 181/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0659 - accuracy: 0.9808
# Epoch 182/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0696 - accuracy: 0.9770
# Epoch 183/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0585 - accuracy: 0.9770
# Epoch 184/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0675 - accuracy: 0.9885
# Epoch 185/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0351 - accuracy: 0.9962
# Epoch 186/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0553 - accuracy: 0.9770
# Epoch 187/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0354 - accuracy: 0.9885
# Epoch 188/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0366 - accuracy: 0.9923
# Epoch 189/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0414 - accuracy: 0.9923
# Epoch 190/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0385 - accuracy: 0.9847
# Epoch 191/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0437 - accuracy: 0.9847
# Epoch 192/200
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0590 - accuracy: 0.9847
# Epoch 193/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1020 - accuracy: 0.9732
# Epoch 194/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0552 - accuracy: 0.9923
# Epoch 195/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1235 - accuracy: 0.9655
# Epoch 196/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0577 - accuracy: 0.9885
# Epoch 197/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0614 - accuracy: 0.9770
# Epoch 198/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0634 - accuracy: 0.9885
# Epoch 199/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0554 - accuracy: 0.9847
# Epoch 200/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0640 - accuracy: 0.9847
# model created
